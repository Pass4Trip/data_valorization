# %%
from src import DA_lib

# %%
DA_lib.show_img('./img/commande_service.png')

# %%
DA_lib.show_img('./img/commande_service_detail.png')

# %% [markdown]
# ## IDENTIFIER LES SERVICES OPEN DATA NECESSAIRES POUR LE UC

# %% [markdown]
# ## INFORMER LES OFFERING MANAGER DES SERVICES RETENUS

# %% [markdown]
# ## ANTICIPER LE, PLANNING DE MISE EN PRODUCTION DES SERVICES DATA

# %% [markdown]
# ## ANTICIPER LES RESSOURCES DEVOPS NECESSAIRES POUR LE PARAMETRAGE DANS L’OPEN DATA
