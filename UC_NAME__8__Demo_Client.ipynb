# %%
from src import DA_lib

# %%
DA_lib.show_img('./img/demo_client.png')

# %% [markdown]
# ## PRESENTER LA SOLUTION EN MODE DEMO

# %% [markdown]
# ## VALIDER (OU NON) LA SOLUTION

# %% [markdown]
# ## COLLECTER LES RETOURS DU CLIENT
