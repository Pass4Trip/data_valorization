# %%
from src import DA_lib

# %%
DA_lib.show_img('./img/doc_viz.png')

# %%
DA_lib.show_img('./img/doc_viz_detail.png')

# %% [markdown]
# ## EXPLIQUER L’OBJECTF DES VISUALISATIONS GENEREES

# %% [markdown]
# ## EXPLIQUER LA CINEMATIQUE DES VISUALISATIONS
