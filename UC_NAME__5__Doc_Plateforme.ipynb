# %%
from src import DA_lib

# %%
DA_lib.show_img('./img/doc_technic.png')

# %%
DA_lib.show_img('./img/doc_technic_detail.png')

# %% [markdown]
# ## SEGEMENTER SON CODE PAR LAYER : INGESTION, PROCESSING & DATA SCIENCE

# %% [markdown]
# ## MODELISER LES TRANSFORMATIONS PAR LAYER

# %% [markdown]
# ## EXPLIQUER LA LOGIQUE DE CHAQUE TRANSFORMATION DANS UN OBJECTIF DE LIGNAGE
