# %%
from src import DA_lib

# %%
DA_lib.show_img('./img/analyse_besoin.png')

# %%
DA_lib.show_img('./img/analyse_besoin_detail.png')

# %% [markdown]
# ## SE PROJETER DANS LE CONTEXTE DU CLIENT ET COMPRENDRE SES PROBLEMES

# %% [markdown]
# ## EXPERIMENTER AVEC DE NOUVELLES DONNEES POUR ESSAYER D’AUGMENTER LA VALEUR AJOUTE

# %% [markdown]
# ## IDENTIFIER LES MACROS SOLUTIONS DE COLLECTE, INGESTION, PROCESSING ET EXPOSITION

# %% [markdown]
# ## S’ASSURER QUE LES SOLUTIONS UTILISEES EN DEV POURRONT ETRE PORTEES VERS L’OPEN DATA

# %% [markdown]
# ## PARTAGER DES IDEES D’AMELIORATIONS ENVISAGEES

# %%
DA_lib.show_img('./img/presentation_hypothese.png')

# %%
DA_lib.show_img('./img/presentation_hypothese_detail.png')

# %% [markdown]
# ## REVALIDER LES BESOINS ET LES OBJECTIFS A ATTEINDRE

# %% [markdown]
# ## VALIDER LES KPI DE SUCCES DU UC

# %% [markdown]
# ## PRESENTER LES ETAPES DE LA COLLECTE DE LA DONNEES, LES PROCESSING ET LES SOLUTIONS DE VISUALISATION DES RESULTATS

# %% [markdown]
# ## PRESENTER LA MAQUETTE THEORIQUE DE LA SOLUTION DATA VIZ

# %% [markdown]
# ## VALIDER (OU NON) LE DEMARRAGE DES DEV DU POC
