# %%
from src import DA_lib

# %%
DA_lib.show_img('/Users/vinhthuy/Documents/ITG/Guide Data Analyst/img/mep.png')

# %%
DA_lib.show_img('/Users/vinhthuy/Documents/ITG/Guide Data Analyst/img/mep_detail.png')

# %% [markdown]
# ## ACCOMPAGNER LES DEVOPS DANS LA MISE EN PRODUCTION ET LE PARAMETRAGE DE L’OPEN DATA

# %% [markdown]
# ## ACCOMPAGNER LE CLIENT DANS SA CONSTRUCTION DES VISUALISATIONS EN PRODUCTION
