# %%
from src import DA_lib

# %%
DA_lib.show_img('./img/constat_existant.png')

# %%
DA_lib.show_img('./img/constat_existant_detail.png')

# %% [markdown]
# ## EXPLIQUER DE FACON SYNTHETIQUE LE PROBLEME

# %% [markdown]
# ## EXPLIQUER LA SOLUTION EXISTANTE ET SES LIMITES

# %% [markdown]
# ## LISTER LES DONNEES UTILISEES PAR LA SOLUTION

# %% [markdown]
# ## LISTER LES MODES DE COLLECTE DES DONNEES UTILISEES

# %% [markdown]
# ## PARTAGER DES IDEES D’AMELIORATIONS ENVISAGEES

# %%
DA_lib.show_img('./img/besoin_formalise.png')

# %%
DA_lib.show_img('./img/besoin_formalise_detail.png')

# %% [markdown]
# ## VALIDER LA COMPREHENSION DU PROBLEME

# %% [markdown]
# ## CHALLENGER LE PROBLEME ET DEDUIRE LES BESOINS / OBJECTIFS

# %% [markdown]
# ## INTEGRER LES IDEES D’AMELIORATIONS DU CLIENT

# %% [markdown]
# ## VALIDER LES GOLDEN SOURCE

# %% [markdown]
# ## VALIDER LES MODES CIBLES DE COLLECTE DES GOLDEN SOURCE
